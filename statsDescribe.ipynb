# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/Users/ermolnik/Desktop/stats.csv', delimiter=";")

# %%
df.head(20)
# Out:
#     DoctorId  OrganizationId  RegionId  PacientCount  Retention  \
# 0       4456               1        50            32     0.1000
# 1      68097               2        50            44     0.0500
# 2       7813               7        50            12     0.0010
# 3     332245               6        50            88     0.1200
# 4     677809               4        50            22     0.0400
# 5     121178               5        50            11     0.0200
# 6     401043               5        50            97     0.1600
# 7     122111               7        50           101     0.1400
# 8    9757681               1        50            43     0.0540
# 9      76164               3        71            10     0.0500
# 10     28998               3        71             8     0.0010
# 11     12681              11        71             7     0.1200
# 12     12442               3        71             2     0.0400
# 13     19988              15        76            89     0.0001
# ...

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a214958d0>,
# ...
#       dtype=object)

# %%
filtered_df = df[df['Mkb10IllnessCode'] == 14]

# %%
df76 = df[df['RegionId'] == 76]

# %%
dfNot76 = df[df['RegionId'] != 76]

# %%
dfNot76.head()
# Out:
#    DoctorId  OrganizationId  RegionId  PacientCount  Retention  ChangeQtyPerc  \
# 0      4456               1        50            32      0.100           0.03
# 1     68097               2        50            44      0.050           0.02
# 2      7813               7        50            12      0.001           0.01
# 3    332245               6        50            88      0.120           0.05
# 4    677809               4        50            22      0.040           0.07
#
#    Duration  Accuracy  Mkb10IllnessCode
# 0        22      0.97                 7
# 1        13      0.98                10
# 2        12      0.99                10
# 3        20      0.88                 7
# 4        11      0.91                10

# %%
sns.kdeplot(df76['Retention'])
sns.rugplot(df76['Retention']);

# %%
sns.kdeplot(dfNot76['Retention'])
sns.rugplot(dfNot76['Retention']);

# %%
sns.lmplot(x = 'Mkb10IllnessCode', y = 'Duration', data = df)

# %%
df.describe()
# Out:
#            DoctorId  OrganizationId  RegionId  PacientCount  Retention  \
# count  2.000000e+01       20.000000  20.00000     20.000000   20.00000
# mean   5.901178e+05        8.100000  63.30000     44.850000    0.05251
# std    2.164708e+06        5.646611  12.47777     32.910205    0.05194
# min    1.870000e+02        1.000000  50.00000      2.000000    0.00010
# 25%    1.247950e+04        3.000000  50.00000     11.750000    0.00675
# 50%    2.449300e+04        6.500000  71.00000     43.000000    0.04000
# 75%    1.214112e+05       14.250000  76.00000     70.250000    0.10000
# max    9.757681e+06       18.000000  76.00000    101.000000    0.16000
#
#        ChangeQtyPerc   Duration   Accuracy  Mkb10IllnessCode
# count      20.000000  20.000000  20.000000         20.000000
# mean        0.075955  17.950000   0.925000         10.200000
# std         0.150426  10.404832   0.049043          2.284962
# min         0.001000   8.000000   0.860000          7.000000
# ...
